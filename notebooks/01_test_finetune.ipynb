# %%
import sys

sys.path.append("/data/volume/grokking_llm")

# %%
from grokking_llm.utils.hf_cache import DS_ARC
from datasets import load_dataset

# %%
from grokking_llm.utils.paths import hf_cache

print(hf_cache)
dataset = load_dataset(DS_ARC, cache_dir=hf_cache)
# Out:
# /data/volume/grokking_llm/hf_cache
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[5], line 4
#       1 from grokking_llm.utils.paths import hf_cache
#       3 print(hf_cache)
# ----> 4 dataset = load_dataset(DS_ARC, cache_dir=hf_cache)
#
# File /data/volume/grokking_llm/.venv/lib/python3.8/site-packages/datasets/load.py:2128, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, **config_kwargs)
#    2123 verification_mode = VerificationMode(
#    2124     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2125 )
#    2127 # Create a dataset builder
# -> 2128 builder_instance = load_dataset_builder(
# ...

# %%
dataset = load_dataset(ARC)
dataset = dataset["train"].train_test_split(test_size=0.1)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 dataset = load_dataset(ARC)
#       2 dataset = dataset["train"].train_test_split(test_size=0.1)
#
# File /data/volume/grokking_llm/.venv/lib/python3.8/site-packages/datasets/load.py:2128, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, **config_kwargs)
#    2123 verification_mode = VerificationMode(
#    2124     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2125 )
#    2127 # Create a dataset builder
# -> 2128 builder_instance = load_dataset_builder(
#    2129     path=path,
#    2130     name=name,
#    2131     data_dir=data_dir,
# ...
